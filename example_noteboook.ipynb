# %%
import wcvpmaps
wcvpmaps.download_data()

# %%
wcvpmaps.SRMapFromFamily("Ericaceae")
# Out:
# Most common climate for Ericaceae: subtropical

# %%
wcvpmaps.SRMapFromFamily("Fabaceae", custom_breaks=[0.6, 60, 150, 250, 400, 500, 750, 1000, 1300, 1543])
# Out:
# Most common climate for Fabaceae: seasonally dry tropical

# %%
wcvpmaps.SRMapFromFamily("Limnanthaceae", 
    custom_breaks=[0.6, 1, 2, 3, 4, 5, 6, 7], 
    custom_labels=[str(x) for x in range(0,8)])
# Out:
# Most common climate for Limnanthaceae: temperate
